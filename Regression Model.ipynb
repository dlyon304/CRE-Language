# %%
import pandas as pd
import numpy as np
import random
import os

import tensorflow as tf
from keras import layers, Input, Model

# %%
def one_hot_seqs(seqs) -> np.array:
    static_1hotmap = {
        'A' : np.array([1,0,0,0]),
        'a' : np.array([1,0,0,0]),
        'C' : np.array([0,1,0,0]),
        'c' : np.array([0,1,0,0]),
        'G' : np.array([0,0,1,0]),
        'g' : np.array([0,0,1,0]),
        'T' : np.array([0,0,0,1]),
        't' : np.array([0,0,0,1]),
    }
    onehot_seqs = []
    for seq in seqs:
        onehot_seqs.append(
            [static_1hotmap[seq[i]] if seq[i] in static_1hotmap.keys() else static_1hotmap[random.choice(['A','C','G','T'])] for i in range(len(seq))]
        )
    return np.stack(onehot_seqs)

# %%
activity_df = pd.read_csv("Data/activity.csv", index_col=0)
test_df = activity_df[activity_df['set'] == 'TEST']
train_df = activity_df[activity_df['set'] == 'TRAIN']

x_train = one_hot_seqs(train_df['sequence'])
x_test = one_hot_seqs(test_df['sequence'])

y_train = train_df['expression_log2'].values
y_test = test_df['expression_log2'].values

# %%
def identity_block(X, f, filters, stage, block):
   
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'
    F1, F2, F3 = filters

    X_shortcut = X
   
    X = layers.Conv1D(filters=F1, kernel_size=1, strides=1, padding='valid', name=conv_name_base + '2a')(X)
    X = layers.BatchNormalization(name=bn_name_base + '2a')(X)
    X = layers.Activation('relu')(X)

    X = layers.Conv1D(filters=F2, kernel_size=f, strides=1, padding='same', name=conv_name_base + '2b')(X)
    X = layers.BatchNormalization(name=bn_name_base + '2b')(X)
    X = layers.Activation('relu')(X)

    X = layers.Conv1D(filters=F3, kernel_size=1, strides=1, padding='valid', name=conv_name_base + '2c')(X)
    X = layers.BatchNormalization(name=bn_name_base + '2c')(X)

    X = layers.Add()([X, X_shortcut])# SKIP Connection
    X = layers.Activation('relu')(X)

    return X

# %%
def convolutional_block(X, f, filters, stage, block, s=2):
   
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    F1, F2, F3 = filters

    X_shortcut = X

    X = layers.Conv1D(filters=F1, kernel_size=1, strides=s, padding='valid', name=conv_name_base + '2a')(X)
    X = layers.BatchNormalization(name=bn_name_base + '2a')(X)
    X = layers.Activation('relu')(X)

    X = layers.Conv1D(filters=F2, kernel_size=f, strides=1, padding='same', name=conv_name_base + '2b')(X)
    X = layers.BatchNormalization(name=bn_name_base + '2b')(X)
    X = layers.Activation('relu')(X)

    X = layers.Conv1D(filters=F3, kernel_size=1, strides=1, padding='valid', name=conv_name_base + '2c')(X)
    X = layers.BatchNormalization(name=bn_name_base + '2c')(X)

    X_shortcut = layers.Conv1D(filters=F3, kernel_size=1, strides=s, padding='valid', name=conv_name_base + '1')(X_shortcut)
    X_shortcut = layers.BatchNormalization(name=bn_name_base + '1')(X_shortcut)

    X = layers.Add()([X, X_shortcut])
    X = layers.Activation('relu')(X)

    return X

# %%
def ResNet50(input_shape=(164,4)):

    X_input = Input(input_shape)

    X = layers.ZeroPadding1D(3)(X_input)

    X = layers.Conv1D(64, 7, strides=2, name='conv1')(X)
    X = layers.BatchNormalization( name='bn_conv1')(X)
    X = layers.Activation('relu')(X)
    X = layers.MaxPooling1D(3, strides=2)(X)

    X = convolutional_block(X, f=3, filters=[64, 64, 256], stage=2, block='a', s=1)
    X = identity_block(X, 3, [64, 64, 256], stage=2, block='b')
    X = identity_block(X, 3, [64, 64, 256], stage=2, block='c')


    X = convolutional_block(X, f=3, filters=[128, 128, 512], stage=3, block='a', s=2)
    X = identity_block(X, 3, [128, 128, 512], stage=3, block='b')
    X = identity_block(X, 3, [128, 128, 512], stage=3, block='c')
    X = identity_block(X, 3, [128, 128, 512], stage=3, block='d')

    X = convolutional_block(X, f=3, filters=[256, 256, 1024], stage=4, block='a', s=2)
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='b')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='c')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='d')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='e')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='f')

    X = X = convolutional_block(X, f=3, filters=[512, 512, 2048], stage=5, block='a', s=2)
    X = identity_block(X, 3, [512, 512, 2048], stage=5, block='b')
    X = identity_block(X, 3, [512, 512, 2048], stage=5, block='c')

    X = layers.AveragePooling1D(2, padding='same')(X)
    
    X = layers.Flatten()(X)
    X = layers.Dense(256, activation='relu')(X)
    X = layers.Dense(128, activation='relu')(X)
    X = layers.Dense(1, activation='linear')(X)
    
    model = Model(inputs=X_input, outputs=X, name='ResNet50')

    return model

# %%
model = ResNet50()
model.summary()
# Out:
# 2024-02-16 16:41:20.232119: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 38374 MB memory:  -> device: 0, name: NVIDIA A100-PCIE-40GB, pci bus id: 0000:5e:00.0, compute capability: 8.0
# Model: "ResNet50"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 164, 4)]             0         []
#
#  zero_padding1d (ZeroPaddin  (None, 170, 4)               0         ['input_1[0][0]']
#  g1D)
#
#  conv1 (Conv1D)              (None, 82, 64)               1856      ['zero_padding1d[0][0]']
#
#  bn_conv1 (BatchNormalizati  (None, 82, 64)               256       ['conv1[0][0]']
#  on)
#
#  activation (Activation)     (None, 82, 64)               0         ['bn_conv1[0][0]']
#
#  max_pooling1d (MaxPooling1  (None, 40, 64)               0         ['activation[0][0]']
#  D)
#
#  res2a_branch2a (Conv1D)     (None, 40, 64)               4160      ['max_pooling1d[0][0]']
#
#  bn2a_branch2a (BatchNormal  (None, 40, 64)               256       ['res2a_branch2a[0][0]']
#  ization)
#
#  activation_1 (Activation)   (None, 40, 64)               0         ['bn2a_branch2a[0][0]']
#
#  res2a_branch2b (Conv1D)     (None, 40, 64)               12352     ['activation_1[0][0]']
#
#  bn2a_branch2b (BatchNormal  (None, 40, 64)               256       ['res2a_branch2b[0][0]']
#  ization)
#
#  activation_2 (Activation)   (None, 40, 64)               0         ['bn2a_branch2b[0][0]']
#
#  res2a_branch2c (Conv1D)     (None, 40, 256)              16640     ['activation_2[0][0]']
#
#  res2a_branch1 (Conv1D)      (None, 40, 256)              16640     ['max_pooling1d[0][0]']
#
#  bn2a_branch2c (BatchNormal  (None, 40, 256)              1024      ['res2a_branch2c[0][0]']
#  ization)
#
#  bn2a_branch1 (BatchNormali  (None, 40, 256)              1024      ['res2a_branch1[0][0]']
#  zation)
#
#  add (Add)                   (None, 40, 256)              0         ['bn2a_branch2c[0][0]',
#                                                                      'bn2a_branch1[0][0]']
#
#  activation_3 (Activation)   (None, 40, 256)              0         ['add[0][0]']
#
#  res2b_branch2a (Conv1D)     (None, 40, 64)               16448     ['activation_3[0][0]']
#
#  bn2b_branch2a (BatchNormal  (None, 40, 64)               256       ['res2b_branch2a[0][0]']
#  ization)
#
#  activation_4 (Activation)   (None, 40, 64)               0         ['bn2b_branch2a[0][0]']
#
#  res2b_branch2b (Conv1D)     (None, 40, 64)               12352     ['activation_4[0][0]']
#
#  bn2b_branch2b (BatchNormal  (None, 40, 64)               256       ['res2b_branch2b[0][0]']
#  ization)
#
#  activation_5 (Activation)   (None, 40, 64)               0         ['bn2b_branch2b[0][0]']
#
#  res2b_branch2c (Conv1D)     (None, 40, 256)              16640     ['activation_5[0][0]']
#
#  bn2b_branch2c (BatchNormal  (None, 40, 256)              1024      ['res2b_branch2c[0][0]']
#  ization)
#
#  add_1 (Add)                 (None, 40, 256)              0         ['bn2b_branch2c[0][0]',
#                                                                      'activation_3[0][0]']
#
#  activation_6 (Activation)   (None, 40, 256)              0         ['add_1[0][0]']
#
#  res2c_branch2a (Conv1D)     (None, 40, 64)               16448     ['activation_6[0][0]']
#
#  bn2c_branch2a (BatchNormal  (None, 40, 64)               256       ['res2c_branch2a[0][0]']
#  ization)
#
#  activation_7 (Activation)   (None, 40, 64)               0         ['bn2c_branch2a[0][0]']
#
#  res2c_branch2b (Conv1D)     (None, 40, 64)               12352     ['activation_7[0][0]']
#
#  bn2c_branch2b (BatchNormal  (None, 40, 64)               256       ['res2c_branch2b[0][0]']
#  ization)
#
#  activation_8 (Activation)   (None, 40, 64)               0         ['bn2c_branch2b[0][0]']
#
#  res2c_branch2c (Conv1D)     (None, 40, 256)              16640     ['activation_8[0][0]']
#
#  bn2c_branch2c (BatchNormal  (None, 40, 256)              1024      ['res2c_branch2c[0][0]']
#  ization)
#
#  add_2 (Add)                 (None, 40, 256)              0         ['bn2c_branch2c[0][0]',
#                                                                      'activation_6[0][0]']
#
#  activation_9 (Activation)   (None, 40, 256)              0         ['add_2[0][0]']
#
#  res3a_branch2a (Conv1D)     (None, 20, 128)              32896     ['activation_9[0][0]']
#
#  bn3a_branch2a (BatchNormal  (None, 20, 128)              512       ['res3a_branch2a[0][0]']
#  ization)
#
#  activation_10 (Activation)  (None, 20, 128)              0         ['bn3a_branch2a[0][0]']
#
#  res3a_branch2b (Conv1D)     (None, 20, 128)              49280     ['activation_10[0][0]']
#
#  bn3a_branch2b (BatchNormal  (None, 20, 128)              512       ['res3a_branch2b[0][0]']
#  ization)
#
#  activation_11 (Activation)  (None, 20, 128)              0         ['bn3a_branch2b[0][0]']
#
#  res3a_branch2c (Conv1D)     (None, 20, 512)              66048     ['activation_11[0][0]']
#
#  res3a_branch1 (Conv1D)      (None, 20, 512)              131584    ['activation_9[0][0]']
#
#  bn3a_branch2c (BatchNormal  (None, 20, 512)              2048      ['res3a_branch2c[0][0]']
#  ization)
#
#  bn3a_branch1 (BatchNormali  (None, 20, 512)              2048      ['res3a_branch1[0][0]']
#  zation)
#
#  add_3 (Add)                 (None, 20, 512)              0         ['bn3a_branch2c[0][0]',
#                                                                      'bn3a_branch1[0][0]']
#
#  activation_12 (Activation)  (None, 20, 512)              0         ['add_3[0][0]']
#
#  res3b_branch2a (Conv1D)     (None, 20, 128)              65664     ['activation_12[0][0]']
#
#  bn3b_branch2a (BatchNormal  (None, 20, 128)              512       ['res3b_branch2a[0][0]']
#  ization)
#
#  activation_13 (Activation)  (None, 20, 128)              0         ['bn3b_branch2a[0][0]']
#
#  res3b_branch2b (Conv1D)     (None, 20, 128)              49280     ['activation_13[0][0]']
#
#  bn3b_branch2b (BatchNormal  (None, 20, 128)              512       ['res3b_branch2b[0][0]']
#  ization)
#
#  activation_14 (Activation)  (None, 20, 128)              0         ['bn3b_branch2b[0][0]']
#
#  res3b_branch2c (Conv1D)     (None, 20, 512)              66048     ['activation_14[0][0]']
#
#  bn3b_branch2c (BatchNormal  (None, 20, 512)              2048      ['res3b_branch2c[0][0]']
#  ization)
#
#  add_4 (Add)                 (None, 20, 512)              0         ['bn3b_branch2c[0][0]',
#                                                                      'activation_12[0][0]']
#
#  activation_15 (Activation)  (None, 20, 512)              0         ['add_4[0][0]']
#
#  res3c_branch2a (Conv1D)     (None, 20, 128)              65664     ['activation_15[0][0]']
#
#  bn3c_branch2a (BatchNormal  (None, 20, 128)              512       ['res3c_branch2a[0][0]']
#  ization)
#
#  activation_16 (Activation)  (None, 20, 128)              0         ['bn3c_branch2a[0][0]']
#
#  res3c_branch2b (Conv1D)     (None, 20, 128)              49280     ['activation_16[0][0]']
#
#  bn3c_branch2b (BatchNormal  (None, 20, 128)              512       ['res3c_branch2b[0][0]']
#  ization)
#
#  activation_17 (Activation)  (None, 20, 128)              0         ['bn3c_branch2b[0][0]']
#
#  res3c_branch2c (Conv1D)     (None, 20, 512)              66048     ['activation_17[0][0]']
#
#  bn3c_branch2c (BatchNormal  (None, 20, 512)              2048      ['res3c_branch2c[0][0]']
#  ization)
#
#  add_5 (Add)                 (None, 20, 512)              0         ['bn3c_branch2c[0][0]',
#                                                                      'activation_15[0][0]']
#
#  activation_18 (Activation)  (None, 20, 512)              0         ['add_5[0][0]']
#
#  res3d_branch2a (Conv1D)     (None, 20, 128)              65664     ['activation_18[0][0]']
#
#  bn3d_branch2a (BatchNormal  (None, 20, 128)              512       ['res3d_branch2a[0][0]']
#  ization)
#
#  activation_19 (Activation)  (None, 20, 128)              0         ['bn3d_branch2a[0][0]']
#
#  res3d_branch2b (Conv1D)     (None, 20, 128)              49280     ['activation_19[0][0]']
#
#  bn3d_branch2b (BatchNormal  (None, 20, 128)              512       ['res3d_branch2b[0][0]']
#  ization)
#
#  activation_20 (Activation)  (None, 20, 128)              0         ['bn3d_branch2b[0][0]']
#
#  res3d_branch2c (Conv1D)     (None, 20, 512)              66048     ['activation_20[0][0]']
#
#  bn3d_branch2c (BatchNormal  (None, 20, 512)              2048      ['res3d_branch2c[0][0]']
#  ization)
#
#  add_6 (Add)                 (None, 20, 512)              0         ['bn3d_branch2c[0][0]',
#                                                                      'activation_18[0][0]']
#
#  activation_21 (Activation)  (None, 20, 512)              0         ['add_6[0][0]']
#
#  res4a_branch2a (Conv1D)     (None, 10, 256)              131328    ['activation_21[0][0]']
#
#  bn4a_branch2a (BatchNormal  (None, 10, 256)              1024      ['res4a_branch2a[0][0]']
#  ization)
#
#  activation_22 (Activation)  (None, 10, 256)              0         ['bn4a_branch2a[0][0]']
#
#  res4a_branch2b (Conv1D)     (None, 10, 256)              196864    ['activation_22[0][0]']
#
#  bn4a_branch2b (BatchNormal  (None, 10, 256)              1024      ['res4a_branch2b[0][0]']
#  ization)
#
#  activation_23 (Activation)  (None, 10, 256)              0         ['bn4a_branch2b[0][0]']
#
#  res4a_branch2c (Conv1D)     (None, 10, 1024)             263168    ['activation_23[0][0]']
#
#  res4a_branch1 (Conv1D)      (None, 10, 1024)             525312    ['activation_21[0][0]']
#
#  bn4a_branch2c (BatchNormal  (None, 10, 1024)             4096      ['res4a_branch2c[0][0]']
#  ization)
#
#  bn4a_branch1 (BatchNormali  (None, 10, 1024)             4096      ['res4a_branch1[0][0]']
#  zation)
#
#  add_7 (Add)                 (None, 10, 1024)             0         ['bn4a_branch2c[0][0]',
#                                                                      'bn4a_branch1[0][0]']
#
#  activation_24 (Activation)  (None, 10, 1024)             0         ['add_7[0][0]']
#
#  res4b_branch2a (Conv1D)     (None, 10, 256)              262400    ['activation_24[0][0]']
#
#  bn4b_branch2a (BatchNormal  (None, 10, 256)              1024      ['res4b_branch2a[0][0]']
#  ization)
#
#  activation_25 (Activation)  (None, 10, 256)              0         ['bn4b_branch2a[0][0]']
#
#  res4b_branch2b (Conv1D)     (None, 10, 256)              196864    ['activation_25[0][0]']
#
#  bn4b_branch2b (BatchNormal  (None, 10, 256)              1024      ['res4b_branch2b[0][0]']
#  ization)
#
#  activation_26 (Activation)  (None, 10, 256)              0         ['bn4b_branch2b[0][0]']
#
#  res4b_branch2c (Conv1D)     (None, 10, 1024)             263168    ['activation_26[0][0]']
#
#  bn4b_branch2c (BatchNormal  (None, 10, 1024)             4096      ['res4b_branch2c[0][0]']
#  ization)
#
#  add_8 (Add)                 (None, 10, 1024)             0         ['bn4b_branch2c[0][0]',
#                                                                      'activation_24[0][0]']
#
#  activation_27 (Activation)  (None, 10, 1024)             0         ['add_8[0][0]']
#
#  res4c_branch2a (Conv1D)     (None, 10, 256)              262400    ['activation_27[0][0]']
#
#  bn4c_branch2a (BatchNormal  (None, 10, 256)              1024      ['res4c_branch2a[0][0]']
#  ization)
#
#  activation_28 (Activation)  (None, 10, 256)              0         ['bn4c_branch2a[0][0]']
#
#  res4c_branch2b (Conv1D)     (None, 10, 256)              196864    ['activation_28[0][0]']
#
#  bn4c_branch2b (BatchNormal  (None, 10, 256)              1024      ['res4c_branch2b[0][0]']
#  ization)
#
#  activation_29 (Activation)  (None, 10, 256)              0         ['bn4c_branch2b[0][0]']
#
#  res4c_branch2c (Conv1D)     (None, 10, 1024)             263168    ['activation_29[0][0]']
#
#  bn4c_branch2c (BatchNormal  (None, 10, 1024)             4096      ['res4c_branch2c[0][0]']
#  ization)
#
#  add_9 (Add)                 (None, 10, 1024)             0         ['bn4c_branch2c[0][0]',
#                                                                      'activation_27[0][0]']
#
#  activation_30 (Activation)  (None, 10, 1024)             0         ['add_9[0][0]']
#
#  res4d_branch2a (Conv1D)     (None, 10, 256)              262400    ['activation_30[0][0]']
#
#  bn4d_branch2a (BatchNormal  (None, 10, 256)              1024      ['res4d_branch2a[0][0]']
#  ization)
#
#  activation_31 (Activation)  (None, 10, 256)              0         ['bn4d_branch2a[0][0]']
#
#  res4d_branch2b (Conv1D)     (None, 10, 256)              196864    ['activation_31[0][0]']
#
#  bn4d_branch2b (BatchNormal  (None, 10, 256)              1024      ['res4d_branch2b[0][0]']
#  ization)
#
#  activation_32 (Activation)  (None, 10, 256)              0         ['bn4d_branch2b[0][0]']
#
#  res4d_branch2c (Conv1D)     (None, 10, 1024)             263168    ['activation_32[0][0]']
#
#  bn4d_branch2c (BatchNormal  (None, 10, 1024)             4096      ['res4d_branch2c[0][0]']
#  ization)
#
#  add_10 (Add)                (None, 10, 1024)             0         ['bn4d_branch2c[0][0]',
#                                                                      'activation_30[0][0]']
#
#  activation_33 (Activation)  (None, 10, 1024)             0         ['add_10[0][0]']
#
#  res4e_branch2a (Conv1D)     (None, 10, 256)              262400    ['activation_33[0][0]']
#
#  bn4e_branch2a (BatchNormal  (None, 10, 256)              1024      ['res4e_branch2a[0][0]']
#  ization)
#
#  activation_34 (Activation)  (None, 10, 256)              0         ['bn4e_branch2a[0][0]']
#
#  res4e_branch2b (Conv1D)     (None, 10, 256)              196864    ['activation_34[0][0]']
#
#  bn4e_branch2b (BatchNormal  (None, 10, 256)              1024      ['res4e_branch2b[0][0]']
#  ization)
#
#  activation_35 (Activation)  (None, 10, 256)              0         ['bn4e_branch2b[0][0]']
#
#  res4e_branch2c (Conv1D)     (None, 10, 1024)             263168    ['activation_35[0][0]']
#
#  bn4e_branch2c (BatchNormal  (None, 10, 1024)             4096      ['res4e_branch2c[0][0]']
#  ization)
#
#  add_11 (Add)                (None, 10, 1024)             0         ['bn4e_branch2c[0][0]',
#                                                                      'activation_33[0][0]']
#
#  activation_36 (Activation)  (None, 10, 1024)             0         ['add_11[0][0]']
#
#  res4f_branch2a (Conv1D)     (None, 10, 256)              262400    ['activation_36[0][0]']
#
#  bn4f_branch2a (BatchNormal  (None, 10, 256)              1024      ['res4f_branch2a[0][0]']
#  ization)
#
#  activation_37 (Activation)  (None, 10, 256)              0         ['bn4f_branch2a[0][0]']
#
#  res4f_branch2b (Conv1D)     (None, 10, 256)              196864    ['activation_37[0][0]']
#
#  bn4f_branch2b (BatchNormal  (None, 10, 256)              1024      ['res4f_branch2b[0][0]']
#  ization)
#
#  activation_38 (Activation)  (None, 10, 256)              0         ['bn4f_branch2b[0][0]']
#
#  res4f_branch2c (Conv1D)     (None, 10, 1024)             263168    ['activation_38[0][0]']
#
#  bn4f_branch2c (BatchNormal  (None, 10, 1024)             4096      ['res4f_branch2c[0][0]']
#  ization)
#
#  add_12 (Add)                (None, 10, 1024)             0         ['bn4f_branch2c[0][0]',
#                                                                      'activation_36[0][0]']
#
#  activation_39 (Activation)  (None, 10, 1024)             0         ['add_12[0][0]']
#
#  res5a_branch2a (Conv1D)     (None, 5, 512)               524800    ['activation_39[0][0]']
#
#  bn5a_branch2a (BatchNormal  (None, 5, 512)               2048      ['res5a_branch2a[0][0]']
#  ization)
#
#  activation_40 (Activation)  (None, 5, 512)               0         ['bn5a_branch2a[0][0]']
#
#  res5a_branch2b (Conv1D)     (None, 5, 512)               786944    ['activation_40[0][0]']
#
#  bn5a_branch2b (BatchNormal  (None, 5, 512)               2048      ['res5a_branch2b[0][0]']
#  ization)
#
#  activation_41 (Activation)  (None, 5, 512)               0         ['bn5a_branch2b[0][0]']
#
#  res5a_branch2c (Conv1D)     (None, 5, 2048)              1050624   ['activation_41[0][0]']
#
#  res5a_branch1 (Conv1D)      (None, 5, 2048)              2099200   ['activation_39[0][0]']
#
#  bn5a_branch2c (BatchNormal  (None, 5, 2048)              8192      ['res5a_branch2c[0][0]']
#  ization)
#
#  bn5a_branch1 (BatchNormali  (None, 5, 2048)              8192      ['res5a_branch1[0][0]']
#  zation)
#
#  add_13 (Add)                (None, 5, 2048)              0         ['bn5a_branch2c[0][0]',
#                                                                      'bn5a_branch1[0][0]']
#
#  activation_42 (Activation)  (None, 5, 2048)              0         ['add_13[0][0]']
#
#  res5b_branch2a (Conv1D)     (None, 5, 512)               1049088   ['activation_42[0][0]']
#
#  bn5b_branch2a (BatchNormal  (None, 5, 512)               2048      ['res5b_branch2a[0][0]']
#  ization)
#
#  activation_43 (Activation)  (None, 5, 512)               0         ['bn5b_branch2a[0][0]']
#
#  res5b_branch2b (Conv1D)     (None, 5, 512)               786944    ['activation_43[0][0]']
#
#  bn5b_branch2b (BatchNormal  (None, 5, 512)               2048      ['res5b_branch2b[0][0]']
#  ization)
#
#  activation_44 (Activation)  (None, 5, 512)               0         ['bn5b_branch2b[0][0]']
#
#  res5b_branch2c (Conv1D)     (None, 5, 2048)              1050624   ['activation_44[0][0]']
#
#  bn5b_branch2c (BatchNormal  (None, 5, 2048)              8192      ['res5b_branch2c[0][0]']
#  ization)
#
#  add_14 (Add)                (None, 5, 2048)              0         ['bn5b_branch2c[0][0]',
#                                                                      'activation_42[0][0]']
#
#  activation_45 (Activation)  (None, 5, 2048)              0         ['add_14[0][0]']
#
#  res5c_branch2a (Conv1D)     (None, 5, 512)               1049088   ['activation_45[0][0]']
#
#  bn5c_branch2a (BatchNormal  (None, 5, 512)               2048      ['res5c_branch2a[0][0]']
#  ization)
#
#  activation_46 (Activation)  (None, 5, 512)               0         ['bn5c_branch2a[0][0]']
#
#  res5c_branch2b (Conv1D)     (None, 5, 512)               786944    ['activation_46[0][0]']
#
#  bn5c_branch2b (BatchNormal  (None, 5, 512)               2048      ['res5c_branch2b[0][0]']
#  ization)
#
#  activation_47 (Activation)  (None, 5, 512)               0         ['bn5c_branch2b[0][0]']
#
#  res5c_branch2c (Conv1D)     (None, 5, 2048)              1050624   ['activation_47[0][0]']
#
#  bn5c_branch2c (BatchNormal  (None, 5, 2048)              8192      ['res5c_branch2c[0][0]']
#  ization)
#
#  add_15 (Add)                (None, 5, 2048)              0         ['bn5c_branch2c[0][0]',
#                                                                      'activation_45[0][0]']
#
#  activation_48 (Activation)  (None, 5, 2048)              0         ['add_15[0][0]']
#
#  average_pooling1d (Average  (None, 3, 2048)              0         ['activation_48[0][0]']
#  Pooling1D)
#
#  flatten (Flatten)           (None, 6144)                 0         ['average_pooling1d[0][0]']
#
#  dense (Dense)               (None, 256)                  1573120   ['flatten[0][0]']
#
#  dense_1 (Dense)             (None, 128)                  32896     ['dense[0][0]']
#
#  dense_2 (Dense)             (None, 1)                    129       ['dense_1[0][0]']
#
# ==================================================================================================
# Total params: 17641409 (67.30 MB)
# Trainable params: 17588289 (67.09 MB)
# Non-trainable params: 53120 (207.50 KB)
# __________________________________________________________________________________________________

# %%
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
history = model.fit(
    x_train,
    y_train,
    batch_size=128,
    epochs=5,
    validation_split=0.2,
)
# Out:
# Epoch 1/5
# 2024-02-16 16:41:42.061430: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8904
# 2024-02-16 16:41:42.169000: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2024-02-16 16:41:42.403945: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2024-02-16 16:41:44.000285: I external/local_xla/xla/service/service.cc:168] XLA service 0x14ac95d903a0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-02-16 16:41:44.000314: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA A100-PCIE-40GB, Compute Capability 8.0
# 2024-02-16 16:41:44.007788: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1708123304.107636 1367634 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 112/112 [==============================] - 45s 83ms/step - loss: 11.8949 - val_loss: 23.1025
# Epoch 2/5
# 112/112 [==============================] - 6s 49ms/step - loss: 7.5782 - val_loss: 24.1821
# Epoch 3/5
# 112/112 [==============================] - 5s 49ms/step - loss: 6.6359 - val_loss: 26.8709
# Epoch 4/5
# 112/112 [==============================] - 5s 49ms/step - loss: 6.0964 - val_loss: 21.6494
# Epoch 5/5
# 112/112 [==============================] - 6s 49ms/step - loss: 4.7715 - val_loss: 16.8119
